# %% [markdown]
# # MISTRAL MODEL INTEGRATED WITH SCRAPING

# %%
from huggingface_hub import login

login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !pip install -q -U bitsandbytes
# !pip install -q -U transformers accelerate
# !pip install -q -U bitsandbytes transformers accelerate
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 34.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 24.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 26.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 109.9 MB/s eta 0:00:00

# %%
# !pip install -q -U bitsandbytes
# !pip install -q -U transformers accelerate

# %%
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

# Use Mistral 7B (quantized)
model_name = "mistralai/Mistral-7B-Instruct-v0.1"

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Load quantized model (4-bit)
bnb_config = BitsAndBytesConfig(load_in_4bit=True, bnb_4bit_use_double_quant=True,
                                bnb_4bit_quant_type="nf4", bnb_4bit_compute_dtype=torch.float16)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map="auto"
)

# Load topics
df = pd.read_csv("/content/final_TRENDS.csv")
topics = df["Processed Data"].dropna().unique()

# Display options
print("📈 Trending Topics:")
for i, topic in enumerate(topics, 1):
    print(f"{i}. {topic}")

# User selects topic
while True:
    try:
        idx = int(input("Choose a topic number: "))
        topic = topics[idx - 1]
        break
    except:
        print("Invalid choice. Try again.")

# Ask for genre
genre = input("Choose genre (e.g., horror, comedy, romance): ").strip()

# Prompt for generation
prompt = (
    f"Write a [{genre}] story about the trending topic: {topic}. "
    f"The story should be highly creative, engaging, and complete with a clear beginning, middle, and end. "
    f"For [{genre}], make sure to include elements typical of the genre — for example, if it's comedy, include jokes, irony, misunderstandings, or exaggeration. "
    f"If it's fantasy, use magic, mythical creatures, or epic adventures. "
    f"If it's horror, build suspense, fear, and a chilling atmosphere.\n\n"
)


# Tokenize and generate
inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
output = model.generate(
    **inputs,
    max_new_tokens=500,
    do_sample=True,
    temperature=0.9,
    top_k=50,
    top_p=0.95,
    pad_token_id=tokenizer.eos_token_id
)

# Decode and print
story = tokenizer.decode(output[0], skip_special_tokens=True)
print("\n📜 Generated Story:\n")
print(story)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# 📈 Trending Topics:
# 1. multan sultans vs quetta gladiators
# 2. kolkata knight riders vs district columbia
# 3. india women vs south africa women
# 4. zulqarnain haider
# 5. canada elections
# 6. federal public service commission central superior services result
# 7. nadra cnic warning
# 8. sardaar ji
# 9. shadman islam
# 10. eobi pension hike
# 11. malaysia vs thailand
# 12. vaibhav suryavanshi age
# 13. power outages
# 14. rahmanullah gurbaz
# 15. venkatesh iyer
# 16. quadcopter
# 17. labour day
# 18. sunil narine
# 19. charli xtreme combat xperience
# 20. andre russell
# 21. arsenal vs psg
# 22. nushki
# 23. xabi alonso
# 24. apagon
# 25. mark kerr
# 26. prime minister gives forces full operational freedom respond jk attack sources
# 27. live liberals win carney says old relationship us
# 28. indian tech entrepreneur kills wife son dies suicide us
# 29. karnataka family visiting pahalgam saved hair literally
# 30. man shouts pakistan zindabad cricket match beaten death
# 31. way traffic javed akhtar pak artistes india jk attack
# 32. ias officer ashok khemka transferred times career retires tomorrow
# 33. pahalgam terror attack updates pms big message forces key security meet
# 34. shubman gills remarks yearold suryavanshis century draw criticism
# 35. canada votes trump says would face zero tariffs
# 36. indian premier league live axar patel pain district columbia captain goes field vs kolkata knight riders
# 37. canada prime minister mark carney closes door trumps takeover plan
# 38. vaibhav suryavanshi whopping cash reward bihar chief minister
# 39. opposition leaders stealing show pahalgam pushback
# 40. even storm comes say allahu akbar jk zipline operators father
# 41. video prokhalistan jagmeet singh breaks crushing canada defeat
# 42. rohit pooran cricketers reacted suryavanshis heroics
# 43. thai king queen pilot plane bhutan land challenging paro airport
# 44. indian mindset destroying european work policies reddit post sparks debate
# 45. yearold vaibhav suryvanshis picture supporting indian premier league team viral
# Choose a topic number: 37
# Choose genre (e.g., horror, comedy, romance): horror
#
# 📜 Generated Story:
#
# Write a [horror] story about the trending topic: canada prime minister mark carney closes door trumps takeover plan. The story should be highly creative, engaging, and complete with a clear beginning, middle, and end. For [horror], make sure to include elements typical of the genre — for example, if it's comedy, include jokes, irony, misunderstandings, or exaggeration. If it's fantasy, use magic, mythical creatures, or epic adventures. If it's horror, build suspense, fear, and a chilling atmosphere.
#
# Prime Minister Mark Carney of Canada had been the head of the country for some time now, but he had a reputation for being a bit unorthodox. He had a tendency to keep things secret, and he was known to be quite protective of his plans. One day, he received a letter from the President of the United States, Donald Trump. The letter stated that he wanted to take over Canada, and he was willing to do whatever it takes to achieve that goal. Prime Minister Carney was horrified, but he knew he had to act quickly if he wanted to save his country.
#
# Carney immediately went into hiding, and he began to work on a plan to stop Trump from taking over Canada. He was determined to find a way to prevent the President from achieving his goal, no matter what it took. After several long days of thinking, he came up with a plan. He would use a magical spell to close the door and keep Trump out of Canada.
#
# Carney went to a secret location where he kept his spellbook, and he began to recite the spell. He focused all his energy on the words, and he felt a surge of power flowing through his body. Suddenly, the door to the Prime Minister's office slammed shut, and a bright light filled the room.
#
# Carney waited for a few minutes, and then he cautiously opened the door again. To his relief, the door was still closed, and there was no sign of Trump. He had successfully used the spell to close the door and keep Trump out of Canada.
#
# But Carney knew that he couldn't rest just yet. He still had to be careful, and he had to make sure that Trump didn't find a way to get into Canada. He began to think of other ways to protect his country, and he knew that he had to act fast.
#
# Just as he was about to come up with a plan, he heard a strange noise coming from the other side of the door. It was a low growl, and it filled him with fear. Suddenly, the door began to shake, and it started to open slowly.
#
# Carney was paralyzed with fear, and he didn't know what to do. He had thought that the spell would keep Trump out of Canada forever, but it seemed that he was wrong. He was about to be overpowered by Trump, and he didn'

# %% [markdown]
# # FEATURES

# %% [markdown]
# # AUDIO TRANS FEATURE

# %%
# !python -m venv storyenv
# !source storyenv/bin/activate  # or storyenv\Scripts\activate on Windows
# !pip install googletrans==4.0.0-rc1
# Out:
# Error: Command '['/content/storyenv/bin/python3', '-m', 'ensurepip', '--upgrade', '--default-pip']' returned non-zero exit status 1.
# /bin/bash: line 1: storyenv/bin/activate: No such file or directory
# Requirement already satisfied: googletrans==4.0.0-rc1 in /usr/local/lib/python3.11/dist-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.11/dist-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2025.1.31)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2025.1.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.11/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.11/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.11/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.11/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# Requirement already satisfied: googletrans==4.0.0-rc1 in /usr/local/lib/python3.11/dist-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.11/dist-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2025.1.31)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2025.1.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.11/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.11/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.11/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.11/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)

# %%
import pandas as pd
from googletrans import Translator, LANGUAGES
from gtts import gTTS
import os
from IPython.display import Audio
import io

# Assume tokenizer and model are already loaded and on CUDA
def process_input(text):
    print("Inside finalnlpbackend: processing ->", text)  # 👈 helps trace call
    # your actual logic here
    return "Processed by backend: " + text

# Load trending topics
df = pd.read_csv("/content/final_TRENDS.csv")
topics = df["Processed Data"].dropna().unique()

print("📈 Trending Topics:")
for i, topic in enumerate(topics, 1):
    print(f"{i}. {topic}")

# Topic selection
while True:
    try:
        idx = int(input("Choose a topic number: "))
        topic = topics[idx - 1]
        break
    except:
        print("Invalid choice. Try again.")

#========================== Genre input ==============================
genre = input("Choose genre (e.g., comedy, horror, fantasy, romance): ").strip()

#======================= Story length input ==========================
while True:
    try:
        length_tokens = int(input("Enter desired story length (number of words/tokens, e.g. 300, 500, 800): "))
        break
    except:
        print("Invalid input. Enter a number.")

#========================== Optional tone ============================
tone = input("Optional: Choose a tone (e.g., funny, poetic, dark) or press Enter to skip: ").strip()
tone_part = f"The tone of the story should be {tone}. " if tone else ""

#====================== Optional characters ==========================
characters = input("Optional: Enter your favorite character(s) (comma-separated), or press Enter to skip: ").strip()

# Base prompt with or without characters
if characters:
    prompt = (
        f"Write a [{genre}] story about the trending topic: {topic}. "
        f"{tone_part}"
        f"The story should include the characters: {characters}. "
        f"It should be highly creative, engaging, and complete with a clear beginning, middle, and end. "
        f"For [{genre}], make sure to include elements typical of the genre — for example, if it's comedy, make plot actually include jokes, irony, misunderstandings, or exaggeration. "
        f"If it's fantasy, use magic, mythical creatures, or epic adventures. "
        f"If it's horror, build suspense, fear, and a chilling atmosphere.\n\n"
        f"Make it a proper short story with a proper start and proper ending with plot twists, very relevant to the theme, "
        f"and of length approximately {length_tokens} words or tokens."
    )
else:
    prompt = (
        f"Write a [{genre}] story about the trending topic: {topic}. "
        f"{tone_part} "
        f"The story should be highly creative, engaging, and complete with a clear beginning, middle, and end. "
        f"For [{genre}], make sure to include elements typical of the genre — for example, if it's comedy, make plot actually include jokes, irony, misunderstandings, or exaggeration. "
        f"If it's fantasy, use magic, mythical creatures, or epic adventures. "
        f"If it's horror, build suspense, fear, and a chilling atmosphere.\n\n"
        f"Make it a proper short story with a proper start and proper ending with plot twists, very relevant to the theme, "
        f"and of length approximately {length_tokens} words or tokens."
    )

#======================= Generate story ==============================
inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
output = model.generate(
    **inputs,
    max_new_tokens=length_tokens,
    do_sample=True,
    temperature=0.9,
    top_k=50,
    top_p=0.95,
    pad_token_id=tokenizer.eos_token_id
)

#========================= Display story =============================
story = tokenizer.decode(output[0], skip_special_tokens=True)
print("\n📜 Generated Story:\n")
print(story)
#======================= Translate story =============================
translator = Translator()
translate_choice = input("\n🌍 Do you want to translate this story to another language? (yes/no): ").strip().lower()

# If user selects 'no', still translate for audio
if translate_choice == "yes":
    print("\nAvailable language codes:")
    for code, lang in LANGUAGES.items():
        print(f"{code}: {lang}")

    target_lang = input("\nEnter target language code for translation: ").strip()
    try:
        translated = translator.translate(story, dest=target_lang)
        story_translated = translated.text
        print(f"\n🌐 Translated Story ({LANGUAGES.get(target_lang, target_lang)}):\n")
        print(story_translated)
    except Exception as e:
        print(f"⚠️ Translation failed: {e}")
        story_translated = story  # Fallback to original


#======================== Audio Narration =============================
audio_choice = input("\n🔊 Do you want to generate audio narration of the story? (yes/no): ").strip().lower()
if audio_choice == "yes":
    # List all supported languages for gTTS
    print("\n🎧 Supported Languages for Audio Narration:")
    for code, lang in LANGUAGES.items():
        print(f"{code}: {lang}")

    # Choose target language for audio narration
    target_lang = input("\nEnter the language code for audio narration: ").strip()

    print(f"\n🎧 Generating and playing audio in: {LANGUAGES.get(target_lang, target_lang).title()}")

    try:
        # Translate the story
        translated = translator.translate(story, dest=target_lang)
        story_translated = translated.text
        print(f"\n🌐 Translated Story ({LANGUAGES.get(target_lang, target_lang)}):\n")

        # Generate and play the audio in the translated language for narration
        tts = gTTS(text=story_translated, lang=target_lang)
        audio_bytes = io.BytesIO()
        tts.write_to_fp(audio_bytes)
        audio_bytes.seek(0)
        display(Audio(audio_bytes.read(), autoplay=True))

    except Exception as e:
        print(f"⚠️ Audio generation failed: {e}")
# Out:
# 📈 Trending Topics:
# 1. multan sultans vs quetta gladiators
# 2. kolkata knight riders vs district columbia
# 3. india women vs south africa women
# 4. zulqarnain haider
# 5. canada elections
# 6. federal public service commission central superior services result
# 7. nadra cnic warning
# 8. sardaar ji
# 9. shadman islam
# 10. eobi pension hike
# 11. malaysia vs thailand
# 12. vaibhav suryavanshi age
# 13. power outages
# 14. rahmanullah gurbaz
# 15. venkatesh iyer
# 16. quadcopter
# 17. labour day
# 18. sunil narine
# 19. charli xtreme combat xperience
# 20. andre russell
# 21. arsenal vs psg
# 22. nushki
# 23. xabi alonso
# 24. apagon
# 25. mark kerr
# 26. prime minister gives forces full operational freedom respond jk attack sources
# 27. live liberals win carney says old relationship us
# 28. indian tech entrepreneur kills wife son dies suicide us
# 29. karnataka family visiting pahalgam saved hair literally
# 30. man shouts pakistan zindabad cricket match beaten death
# 31. way traffic javed akhtar pak artistes india jk attack
# 32. ias officer ashok khemka transferred times career retires tomorrow
# 33. pahalgam terror attack updates pms big message forces key security meet
# 34. shubman gills remarks yearold suryavanshis century draw criticism
# 35. canada votes trump says would face zero tariffs
# 36. indian premier league live axar patel pain district columbia captain goes field vs kolkata knight riders
# 37. canada prime minister mark carney closes door trumps takeover plan
# 38. vaibhav suryavanshi whopping cash reward bihar chief minister
# 39. opposition leaders stealing show pahalgam pushback
# 40. even storm comes say allahu akbar jk zipline operators father
# 41. video prokhalistan jagmeet singh breaks crushing canada defeat
# 42. rohit pooran cricketers reacted suryavanshis heroics
# 43. thai king queen pilot plane bhutan land challenging paro airport
# 44. indian mindset destroying european work policies reddit post sparks debate
# 45. yearold vaibhav suryvanshis picture supporting indian premier league team viral
# Choose a topic number: 45
# Choose genre (e.g., comedy, horror, fantasy, romance): comedy
# Enter desired story length (number of words/tokens, e.g. 300, 500, 800): 300
# Optional: Choose a tone (e.g., funny, poetic, dark) or press Enter to skip: funny
# Optional: Enter your favorite character(s) (comma-separated), or press Enter to skip: ali,sara
#
# 📜 Generated Story:
#
# Write a [comedy] story about the trending topic: yearold vaibhav suryvanshis picture supporting indian premier league team viral. The tone of the story should be funny. The story should include the characters: ali,sara. It should be highly creative, engaging, and complete with a clear beginning, middle, and end. For [comedy], make sure to include elements typical of the genre — for example, if it's comedy, make plot actually include jokes, irony, misunderstandings, or exaggeration. If it's fantasy, use magic, mythical creatures, or epic adventures. If it's horror, build suspense, fear, and a chilling atmosphere.
#
# Make it a proper short story with a proper start and proper ending with plot twists, very relevant to the theme, and of length approximately 300 words or tokens.
#
# **Ali and Sara were two college friends who had always been an avid fan of the Indian Premier League (IPL). They would often be seen at the stadiums, supporting their favorite team, and sometimes they would even make fun of their rival teams. One day, they stumbled upon a picture of a yearold Vaibhav Survanshi supporting the IPL team and sharing it on social media. This picture instantly went viral and soon the entire internet was talking about it.
#
# As they read the comments on the picture, they noticed that people were praising Vaibhav's enthusiasm and passion for the sport. Ali and Sara were impressed and decided to share the picture on their own social media accounts.
#
# To their surprise, the picture also went viral on their accounts and soon they were getting messages from people asking about Vaibhav Survanshi. They realized that they had become influencers in the IPL community and people were looking up to them for advice and recommendations.
#
# Ali and Sara were thrilled about the attention they were receiving and decided to organize a meet-and-greet event with Vaibhav Survanshi. They sent him a message asking if he would be willing to meet them and Vaibhav, being a huge fan of IPL, immediately agreed.
#
# The day of the meet-and-greet event arrived and Ali and Sara were nervous about meeting Vaibhav. They
#
# 🌍 Do you want to translate this story to another language? (yes/no): no
#
# 🔊 Do you want to generate audio narration of the story? (yes/no): yes
#
# 🎧 Supported Languages for Audio Narration:
# af: afrikaans
# sq: albanian
# am: amharic
# ar: arabic
# hy: armenian
# az: azerbaijani
# eu: basque
# be: belarusian
# bn: bengali
# bs: bosnian
# bg: bulgarian
# ca: catalan
# ceb: cebuano
# ny: chichewa
# zh-cn: chinese (simplified)
# zh-tw: chinese (traditional)
# co: corsican
# hr: croatian
# cs: czech
# da: danish
# nl: dutch
# en: english
# eo: esperanto
# et: estonian
# tl: filipino
# fi: finnish
# fr: french
# fy: frisian
# gl: galician
# ka: georgian
# de: german
# el: greek
# gu: gujarati
# ht: haitian creole
# ha: hausa
# haw: hawaiian
# iw: hebrew
# he: hebrew
# hi: hindi
# hmn: hmong
# hu: hungarian
# is: icelandic
# ig: igbo
# id: indonesian
# ga: irish
# it: italian
# ja: japanese
# jw: javanese
# kn: kannada
# kk: kazakh
# km: khmer
# ko: korean
# ku: kurdish (kurmanji)
# ky: kyrgyz
# lo: lao
# la: latin
# lv: latvian
# lt: lithuanian
# lb: luxembourgish
# mk: macedonian
# mg: malagasy
# ms: malay
# ml: malayalam
# mt: maltese
# mi: maori
# mr: marathi
# mn: mongolian
# my: myanmar (burmese)
# ne: nepali
# no: norwegian
# or: odia
# ps: pashto
# fa: persian
# pl: polish
# pt: portuguese
# pa: punjabi
# ro: romanian
# ru: russian
# sm: samoan
# gd: scots gaelic
# sr: serbian
# st: sesotho
# sn: shona
# sd: sindhi
# si: sinhala
# sk: slovak
# sl: slovenian
# so: somali
# es: spanish
# su: sundanese
# sw: swahili
# sv: swedish
# tg: tajik
# ta: tamil
# te: telugu
# th: thai
# tr: turkish
# uk: ukrainian
# ur: urdu
# ug: uyghur
# uz: uzbek
# vi: vietnamese
# cy: welsh
# xh: xhosa
# yi: yiddish
# yo: yoruba
# zu: zulu
#
# Enter the language code for audio narration: ur
#
# 🎧 Generating and playing audio in: Urdu
#
# 🌐 Translated Story (urdu):
#
# رجحان سازی کے موضوع کے بارے میں ایک [مزاحیہ] کہانی لکھیں: یئرڈ وبھو سوریوینشیس تصویر جس میں ہندوستانی پریمیر لیگ ٹیم وائرل کی حمایت کی جارہی ہے۔کہانی کا لہجہ مضحکہ خیز ہونا چاہئے۔کہانی میں کردار شامل ہونا چاہئے: علی ، سارہ۔یہ انتہائی تخلیقی ، مشغول اور واضح آغاز ، وسط اور اختتام کے ساتھ مکمل ہونا چاہئے۔[کامیڈی] کے ل the ، اس صنف کے مخصوص عناصر کو شامل کرنا یقینی بنائیں - مثال کے طور پر ، اگر یہ مزاحیہ ہے تو ، پلاٹ بنائیں دراصل لطیفے ، ستم ظریفی ، غلط فہمیوں یا مبالغہ آرائی کو شامل کریں۔اگر یہ خیالی ہے تو ، جادو ، افسانوی مخلوق ، یا مہاکاوی مہم جوئی کا استعمال کریں۔اگر یہ ہارر ہے تو ، سسپنس ، خوف اور ٹھنڈک ماحول پیدا کریں۔
#
# اس کو ایک مناسب اسٹارٹ اور پلاٹ کے موڑ کے ساتھ مناسب اختتام کے ساتھ ایک مناسب مختصر کہانی بنائیں ، جو تھیم سے بہت ہی متعلقہ ہیں ، اور لمبائی کے لگ بھگ 300 الفاظ یا ٹوکن ہیں۔
#
# ** علی اور سارہ دو کالج دوست تھے جو ہمیشہ انڈین پریمیر لیگ (آئی پی ایل) کے شوق پرست پرستار رہے تھے۔وہ اکثر اسٹیڈیم میں نظر آتے ، اپنی پسندیدہ ٹیم کی حمایت کرتے تھے ، اور بعض اوقات وہ اپنی حریف ٹیموں کا مذاق اڑاتے بھی کرتے تھے۔ایک دن ، انہوں نے آئی پی ایل کی ٹیم کی حمایت کرنے اور اسے سوشل میڈیا پر شیئر کرنے کے لئے ایک یارڈ وبھو سروینشی کی تصویر سے ٹھوکر کھائی۔یہ تصویر فوری طور پر وائرل ہوگئی اور جلد ہی پورا انٹرنیٹ اس کے بارے میں بات کر رہا تھا۔
#
# جب انہوں نے تصویر پر تبصرے پڑھے تو انہوں نے دیکھا کہ لوگ وہبھو کے جوش و جذبے اور کھیل کے جذبے کی تعریف کر رہے ہیں۔علی اور سارہ متاثر ہوئے اور انہوں نے تصویر اپنے سوشل میڈیا اکاؤنٹس پر شیئر کرنے کا فیصلہ کیا۔
#
# حیرت کی بات یہ ہے کہ تصویر بھی ان کے کھاتوں پر وائرل ہوگئی اور جلد ہی انہیں لوگوں سے وبھو سروینشی کے بارے میں پوچھتے ہوئے پیغامات مل رہے تھے۔انہوں نے محسوس کیا کہ وہ آئی پی ایل برادری میں اثر و رسوخ بن چکے ہیں اور لوگ مشورے اور سفارشات کے لئے ان کی تلاش کر رہے ہیں۔
#
# علی اور سارہ کو وہ توجہ حاصل کرنے پر بہت خوشی ہوئی اور انہوں نے وبھو سروینشی کے ساتھ ملاقات اور گریٹ ایونٹ کا اہتمام کرنے کا فیصلہ کیا۔انہوں نے اسے ایک پیغام بھیجا جس میں یہ پوچھا گیا کہ کیا وہ ان سے ملنے کے لئے راضی ہوگا اور وہبھو ، آئی پی ایل کا ایک بہت بڑا پرستار ہونے کے ناطے ، فورا. ہی راضی ہوگیا۔
#
# ملاقات اور مبارکباد کے پروگرام کا دن آگیا اور علی اور سارہ وابھو سے ملنے سے گھبر رہے تھے۔وہ
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install gTTS
# Out:
# Requirement already satisfied: gTTS in /usr/local/lib/python3.11/dist-packages (2.5.4)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from gTTS) (2.32.3)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.11/dist-packages (from gTTS) (8.1.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->gTTS) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->gTTS) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->gTTS) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->gTTS) (2025.1.31)

# %%
# !pip install googletrans==4.0.0-rc1 gTTS IPython
# Out:
# Requirement already satisfied: googletrans==4.0.0-rc1 in /usr/local/lib/python3.11/dist-packages (4.0.0rc1)
# Requirement already satisfied: gTTS in /usr/local/lib/python3.11/dist-packages (2.5.4)
# Requirement already satisfied: IPython in /usr/local/lib/python3.11/dist-packages (7.34.0)
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.11/dist-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2025.1.31)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2025.1.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.11/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.11/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.11/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.11/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.11/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from gTTS) (2.32.3)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.11/dist-packages (from gTTS) (8.1.8)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from IPython) (75.2.0)
# Collecting jedi>=0.16 (from IPython)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from IPython) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from IPython) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from IPython) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from IPython) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from IPython) (2.19.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from IPython) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from IPython) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from IPython) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->IPython) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->IPython) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->gTTS) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->gTTS) (2.4.0)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 27.7 MB/s eta 0:00:00
# Installing collected packages: jedi
# Successfully installed jedi-0.19.2
